# %% [markdown]
# # lag-lock uncertainty\n\nPhase 2 notebook walkthrough.

# %%
import pandas as pd\nfrom lag_lock_uncertainty import LagLockUncertaintyCalculator\n

# %%
df = pd.read_csv("lag_lock_uncertainty_dataset.csv")\ndf.head()\n

# %%
calc = LagLockUncertaintyCalculator()\nresult = calc.calculate_lag_lock_uncertainty(df)\nresult.head()\n

# %%
result["lag_lock_uncertainty_index"].describe()\n

# %%
result.groupby("lag_lock_uncertainty_band").size()\n

# %%
result["lag_lock_uncertainty_index"].hist(bins=20)\n

# %% [markdown]
# Interpretation: `lag-lock uncertainty` index is now ready for stress testing.
